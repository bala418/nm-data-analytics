# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['age'].mean()
# Out:
# 39.20702541106129

# %%
df['charges'].median()
# Out:
# 9382.033

# %%
df['bmi'].mode()
# Out:
# 0    32.3
# Name: bmi, dtype: float64

# %%
df['bmi'].var()
# Out:
# 37.18788360977323

# %%
df['bmi'].std()
# Out:
# 6.098186911679014

# %%
# univariate analysis of age column
df['age'].describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
sns.displot(df['age'])

# %%
sns.countplot(data=df, x='region')
# Out:
# <AxesSubplot: xlabel='region', ylabel='count'>

# %%
sns.countplot(data=df, x='smoker')
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='count'>

# %%
sns.catplot(x='bmi',kind='box',data=df)

# %%
x = df['region'].value_counts()
plt.pie(x.values,labels=x.index,autopct='%1.1f%%')
plt.show()

# %%
x2 = df['smoker'].value_counts()
plt.pie(x2.values,labels=x2.index,autopct='%1.1f%%')
plt.show()

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.kdeplot(df['age'],fill='True')
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(5,5))
plt.violinplot(df['age'],showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1838da4a950>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1838da55b10>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1838da61c50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1838da63a50>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x1838da60e50>}
